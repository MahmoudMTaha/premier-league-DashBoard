# %%
import pandas as pd
import numpy as np
import plotly.express as px
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input,Output,State

# %%
df=pd.read_csv('results.csv',encoding='cp949',)
l=df['Season'].to_list()
ll=[i[0:4]for i in l]
df['Season']=ll
df.head()
# Out:
#   Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0   1993  1993-08-14T00:00:00Z      Arsenal        Coventry     0     3   A
# 1   1993  1993-08-14T00:00:00Z  Aston Villa             QPR     4     1   H
# 2   1993  1993-08-14T00:00:00Z      Chelsea       Blackburn     1     2   A
# 3   1993  1993-08-14T00:00:00Z    Liverpool  Sheffield Weds     2     0   H
# 4   1993  1993-08-14T00:00:00Z     Man City           Leeds     1     1   D
#
#    HTHG  HTAG  HTR  ... HST  AST  HC  AC  HF  AF  HY  AY  HR  AR
# 0   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 23 columns]

# %%
df.Season.unique()
# Out:
# array(['1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020'], dtype=object)

# %%
df.DateTime.dtype
# Out:
# dtype('O')

# %%
df['DateTime']=pd.to_datetime(df['DateTime'])
df['Season']=df['Season'].astype(int)

# %%
df=df[df['Season']>=2010]

# %%
df.head()
# Out:
#       Season                  DateTime     HomeTeam    AwayTeam  FTHG  FTAG  \
# 6624    2010 2010-08-14 00:00:00+00:00  Aston Villa    West Ham     3     0
# 6625    2010 2010-08-14 00:00:00+00:00    Blackburn     Everton     1     0
# 6626    2010 2010-08-14 00:00:00+00:00       Bolton      Fulham     0     0
# 6627    2010 2010-08-14 00:00:00+00:00      Chelsea   West Brom     6     0
# 6628    2010 2010-08-14 00:00:00+00:00   Sunderland  Birmingham     2     2
#
#      FTR  HTHG  HTAG HTR  ...   HST   AST    HC   AC    HF    AF   HY   AY  \
# 6624   H   2.0   0.0   H  ...  11.0   2.0  16.0  7.0  15.0  15.0  1.0  2.0
# 6625   H   1.0   0.0   H  ...   2.0  12.0   1.0  3.0  19.0  14.0  2.0  1.0
# 6626   D   0.0   0.0   D  ...   9.0   7.0   4.0  8.0  12.0  13.0  1.0  3.0
# 6627   H   2.0   0.0   H  ...  13.0   4.0   3.0  1.0  10.0  10.0  1.0  0.0
# 6628   D   1.0   0.0   H  ...   2.0   7.0   3.0  6.0  13.0  10.0  3.0  3.0
#
#        HR   AR
# 6624  0.0  0.0
# 6625  0.0  0.0
# ...

# %% [markdown]
# # Feature Engineering

# %%
df['total_goals']=df['FTHG']+df['FTAG']

# %%
df2=pd.DataFrame(df.groupby(df.Season)['total_goals'].sum())
df2=df2.reset_index()
df2
# Out:
#     Season  total_goals
# 0     2010         1063
# 1     2011         1066
# 2     2012         1063
# 3     2013         1052
# 4     2014          975
# 5     2015         1026
# 6     2016         1064
# 7     2017         1018
# 8     2018         1072
# 9     2019         1034
# 10    2020         1024

# %%
df3=df.copy()
df3=pd.DataFrame(df3[df['FTR'] =='H'].groupby([df.Season,'HomeTeam']).agg({'total_goals':'sum','FTR':'count'}))
df3=df3.reset_index()
df3[df3['Season']==2018]
# Out:
#      Season        HomeTeam  total_goals  FTR
# 160    2018         Arsenal           45   14
# 161    2018     Bournemouth           23    8
# 162    2018        Brighton           13    6
# 163    2018         Burnley           17    7
# 164    2018         Cardiff           17    6
# 165    2018         Chelsea           38   12
# 166    2018  Crystal Palace           15    5
# 167    2018         Everton           24   10
# 168    2018          Fulham           21    6
# 169    2018    Huddersfield            2    2
# 170    2018       Leicester           23    8
# 171    2018       Liverpool           63   17
# 172    2018        Man City           64   18
# 173    2018      Man United           39   10
# 174    2018       Newcastle           23    8
# 175    2018     Southampton           17    5
# 176    2018       Tottenham           34   12
# 177    2018         Watford           25    8
# 178    2018        West Ham           36    9
# ...

# %%
df3['HomeTeam'].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Birmingham', 'Blackburn', 'Blackpool',
#        'Bolton', 'Chelsea', 'Everton', 'Fulham', 'Liverpool', 'Man City',
#        'Man United', 'Newcastle', 'Stoke', 'Sunderland', 'Tottenham',
#        'West Brom', 'West Ham', 'Wigan', 'Wolves', 'Norwich', 'QPR',
#        'Swansea', 'Reading', 'Southampton', 'Cardiff', 'Crystal Palace',
#        'Hull', 'Burnley', 'Leicester', 'Bournemouth', 'Watford',
#        'Middlesbrough', 'Brighton', 'Huddersfield', 'Sheffield United',
#        'Leeds'], dtype=object)

# %%
df4=df.copy()
home_wins=df4[df['FTR'] =='H'].groupby([df.Season,'HomeTeam']).agg({'FTR':'count','FTHG':'sum'}).reset_index()
home_wins.rename(columns={'FTR':'HomeWins'},inplace=True)
home_draw=df4[df['FTR'] =='D'].groupby([df.Season,'HomeTeam']).agg({'FTR':'count','FTHG':'sum'}).reset_index()
home_draw.rename(columns={'FTR':'HomeDraw'},inplace=True)
away_wins=df4[df['FTR'] =='A'].groupby([df.Season,'AwayTeam']).agg({'FTR':'count','FTAG':'sum'}).reset_index()
away_wins.rename(columns={'FTR':'AwayWins'},inplace=True)
away_draw=df4[df['FTR'] =='D'].groupby([df.Season,'AwayTeam']).agg({'FTR':'count','FTAG':'sum'}).reset_index()
away_draw.rename(columns={'FTR':'AwayDraw'},inplace=True)
away_draw[away_draw['AwayTeam']=='Chelsea']
# Out:
#      Season AwayTeam  AwayDraw  FTAG
# 6      2010  Chelsea         5     3
# 24     2011  Chelsea         7     4
# 42     2012  Chelsea         4     5
# 63     2013  Chelsea         4     2
# 83     2014  Chelsea         5     3
# 103    2015  Chelsea         5     3
# 123    2016  Chelsea         3     4
# 144    2017  Chelsea         3     3
# 165    2018  Chelsea         3     1
# 184    2019  Chelsea         3     5
# 203    2020  Chelsea         4     4

# %%
df5=pd.merge(left=home_wins,right=away_wins,left_on=['Season','HomeTeam'],right_on=['Season','AwayTeam'])
df5.drop('AwayTeam',axis=1,inplace=True)
df5.rename(columns={'HomeTeam':'Team'},inplace=True)
df5[df5['Season']==2018]
# Out:
#      Season            Team  HomeWins  FTHG  AwayWins  FTAG
# 160    2018         Arsenal        14    37         7    18
# 161    2018     Bournemouth         8    19         5    16
# 162    2018        Brighton         6    10         3     5
# 163    2018         Burnley         7    15         4    10
# 164    2018         Cardiff         6    13         4     7
# 165    2018         Chelsea        12    33         9    21
# 166    2018  Crystal Palace         5    12         9    22
# 167    2018         Everton        10    22         5    13
# 168    2018          Fulham         6    15         1     1
# 169    2018    Huddersfield         2     2         1     2
# 170    2018       Leicester         8    19         7    13
# 171    2018       Liverpool        17    54        13    30
# 172    2018        Man City        18    55        14    35
# 173    2018      Man United        10    27         9    21
# 174    2018       Newcastle         8    18         4     8
# ...

# %%
df6=pd.merge(left=home_draw,right=away_draw,left_on=['Season','HomeTeam'],right_on=['Season','AwayTeam'],how='right')

df6.drop('AwayTeam',axis=1,inplace=True)
df6.rename(columns={'HomeTeam':'Team'},inplace=True)
df6.loc[123,['Team','HomeDraw','FTHG']]=['Chelsea',0,0]
df6.loc[47,['Team','HomeDraw','FTHG']]=['Man United',0,0]
df6.loc[172,['Team','HomeDraw','FTHG']]=['Man City',0,0]
df6[df6['Season']==2018]
# Out:
#      Season            Team  HomeDraw  FTHG  AwayDraw  FTAG
# 160    2018         Arsenal       3.0   3.0         4     6
# 161    2018     Bournemouth       5.0   8.0         1     3
# 162    2018        Brighton       5.0   5.0         4     5
# 163    2018         Burnley       2.0   2.0         5     4
# 164    2018         Cardiff       2.0   0.0         2     0
# 165    2018         Chelsea       6.0   6.0         3     1
# 166    2018  Crystal Palace       5.0   3.0         2     1
# 167    2018         Everton       4.0   4.0         5     6
# 168    2018          Fulham       3.0   3.0         2     2
# 169    2018    Huddersfield       3.0   2.0         4     3
# 170    2018       Leicester       3.0   1.0         4     5
# 171    2018       Liverpool       2.0   1.0         5     3
# 172    2018        Man City       0.0   0.0         2     1
# 173    2018      Man United       6.0   6.0         3     5
# 174    2018       Newcastle       1.0   0.0         8     6
# ...

# %%
df7=pd.merge(left=df5,right=df6,left_on=['Season','Team'],right_on=['Season','Team'])

# %%
df7['TotalWins']=df7['HomeWins']+df7['AwayWins']
df7['TotalDraw']=df7['HomeDraw']+df7['AwayDraw']
df7['TotalPoints'] = 3*df7['TotalWins'] + df7['TotalDraw']
df7['TeamGoals']=df7['FTHG_x']+df7['FTAG_x']+df7['FTHG_y']+df7['FTAG_y']

# %%
df7['TeamRank']=df7.groupby('Season')['TotalPoints'].rank(method='min',ascending=False)

# %%
df7=df7[df7['TeamRank']==1]
df7=df7.drop_duplicates(subset=['Season'],keep='first')
df7
# Out:
#      Season        Team  HomeWins  FTHG_x  AwayWins  FTAG_x  HomeDraw  FTHG_y  \
# 11     2010  Man United        18      47         5      15       1.0     2.0
# 28     2011    Man City        18      52        10      33       1.0     3.0
# 47     2012  Man United        16      42        12      31       0.0     0.0
# 69     2013    Man City        17      61        10      30       1.0     2.0
# 83     2014     Chelsea        15      32        11      30       4.0     4.0
# 106    2015   Leicester        12      27        11      24       6.0     6.0
# 123    2016     Chelsea        17      53        13      26       0.0     0.0
# 150    2017    Man City        16      58        16      41       2.0     1.0
# 172    2018    Man City        18      55        14      35       0.0     0.0
# 188    2019   Liverpool        18      51        14      31       1.0     1.0
# 209    2020    Man City        13      37        14      36       2.0     2.0
#
# ...

# %%
df8=df.copy()
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4180 entries, 6624 to 10803
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season       4180 non-null   int32
#  1   DateTime     4180 non-null   datetime64[ns, UTC]
#  2   HomeTeam     4180 non-null   object
#  3   AwayTeam     4180 non-null   object
#  4   FTHG         4180 non-null   int64
#  5   FTAG         4180 non-null   int64
#  6   FTR          4180 non-null   object
#  7   HTHG         4180 non-null   float64
#  8   HTAG         4180 non-null   float64
#  9   HTR          4180 non-null   object
#  10  Referee      4180 non-null   object
#  11  HS           4180 non-null   float64
#  12  AS           4180 non-null   float64
#  13  HST          4180 non-null   float64
#  14  AST          4180 non-null   float64
#  15  HC           4180 non-null   float64
#  16  AC           4180 non-null   float64
#  17  HF           4180 non-null   float64
# ...

# %% [markdown]
# # DashBoard

# %%
import dash
import dash_bootstrap_components as dbc

app = dash.Dash(external_stylesheets=[dbc.themes.VAPOR])
#app=dash.Dash(external_stylesheets=['https://codepen.io/chriddyp/pen/bWLwgP.css'])

# %%
app.layout=html.Div([
    html.Img(src="/assets/PL_LOGO_2 (1).png",style = {'height' : '150px'},className="rounded mx-auto d-block"),
    html.Div([
    html.Div([
        html.H5('Premier League Winners With Total Points Over Last 10 Season',style={'textAlign':'center'},className = 'card-header'),
        html.Div([
            dcc.Graph(id='g3',figure=px.line(df7,x='Season',y='TotalPoints',labels={'Season':'Season','TotalPoints':'Total Points'},text='Team').update_traces(textposition="bottom center").add_hline(y=df7['TotalPoints'].mean(),line_color='red',annotation_text='Avg Total Points')
                     )
        ],className = 'card-body')
        
    ],className='card border-secondary  mb-1 col-md'),
    html.Div([
        html.H5('Total Goals Per Season',style={'textAlign':'center'},className = 'card-header'),
        html.Div([
            dcc.Graph(id='g1',
                      figure=px.line(df2,x='Season',y='total_goals',markers=True,text='total_goals',
                                     labels={'Season':'Season','total_goals':'Goals Per Season'}).update_traces(textposition="bottom right")
    )
        ],className = 'card-body')
        
    ],className='card border-secondary  mb-1 col-md'),
    ],className = 'row g-md-1'),
    html.Div([        
        html.Div([
        html.H5('Teams Home Wins and Goals Per Season',style={'textAlign':'center'},className = 'card-header'),
        html.Div([
            dcc.Graph(id='g4',
                      figure=px.scatter(df3,x='total_goals',y='FTR',color='HomeTeam',labels={'total_goals':'Total Number of Goals','FTR':'Number Of Wins'},animation_frame="Season",symbol='HomeTeam',text='HomeTeam').update_traces(textposition="top center",mode='markers+lines')
                     ),
        html.Div([
            html.H5(children="Select Season", style={"fontSize":"150%"}),
            dcc.Slider(
                id='my-slider10',
                min=df3.Season.min(),
                max=df3.Season.max(),
                step=None,value=df3.Season.min(),
                className = 'form-range',
                marks={str(year): str(year) for year in df3.Season.unique()}),
        ], className='six columns'),
        ],className = 'card-body')
        
    ],className='card border-primary  mb-1 col-md'),
    ],className = 'row g-md-1'),
    html.Div([
                html.H4('Teams Performance',style={'textAlign':'center'},className = 'card-header'),
            html.Div([
        html.Div([
            html.Div([
                html.H1(className = "card-text text-center",id='team_name')
            ],className = "card-body"),
        ],className = "card border-success  mb-1 col col-md-3"),
        html.Div([
            html.Div([
                html.H4(className = "card-title text-center",id='Matches'),
                html.P(['Match'],className = "card-text text-center")
            ],className = "card-body"),
        ],className = "card text-white bg-success mb-1 col col-md-2"),
        html.Div([
            html.Div([
                html.H4(className = "card-title text-center",id='season'),
                html.P(['season'],className = "card-text text-center")
            ],className = "card-body"),
        ],className = "card text-white bg-success mb-1 col col-md-2"),
        html.Div([
            html.Div([
                html.H4(className = "card-title text-center",id='win_rate'),
                html.P(['Win %'],className = "card-text text-center")
            ],className = "card-body"),
        ],className = "card text-white bg-success mb-1 col col-md-2"),
        html.Div([
            html.Div([
                html.H4(className = "card-title text-center",id='goals_rate'),
                html.P(['Goal Per Game'],className = "card-text text-center")
            ],className = "card-body"),
        ],className = "card text-white bg-success  mb-1 col col-md-2"),
    ],className = 'row justify-content-sm-center'),

    html.Div([
    html.Div([
    html.Div([

        html.Button(id='Arsenal',
                    style={'background':'url("/assets/Arsenal_FC.png")',
                            'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Aston Villa',
                    style={'background':'url("/assets/aston-villa-logo-1.png")',
                            'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Birmingham',
                    style={'background':'url("/assets/Birmingham_City_FC_logo.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
         html.Button(id='Blackburn',
                    style={'background':'url("/assets/Blackburn1.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Blackpool',
                    style={'background':'url("/assets/Blackpool.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Bolton',
                    style={'background':'url("/assets/Bolton.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Chelsea',
                    style={'background':'url("/assets/Chelsea-logo.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Everton',
                    style={'background':'url("/assets/everton-logo-escudo.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Fulham',
                    style={'background':'url("/assets/fulham-fc-logo-EBBC39136A-seeklogo.com.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Liverpool',
                    style={'background':'url("/assets/Liverpool.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Man City',
                    style={'background':'url("/assets/man city.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        html.Button(id='Man United',
                    style={'background':'url("/assets/man united.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        ],className='col d-flex btn-group-vertical'),
        html.Div([

        html.Button(id='Newcastle',
                    style={'background':'url("/assets/newcastle-united-fc-logo-58D461B354-seeklogo.com.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='Stoke',
                    style={'background':'url("/assets/20170617223424!Stoke_City_FC.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='Sunderland',
                    style={'background':'url("/assets/Sunderland.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='Tottenham',value = 'Tottenham',
                    style={'background':'url("/assets/Tottenham_Hotspur_Badge.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='West Brom',
                    style={'background':'url("/assets/West_Bromwich_Albion.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='West Ham',
                    style={'background':'url("/assets/west-ham-united-fc-2-logo-png-transparent.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='Wigan',
                    style={'background':'url("/assets/wigan-athletic-logo-png-transparent.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='Wolves',
                    style={'background':'url("/assets/kisspng-molineux-stadium-wolverhampton-wanderers-f-c-efl-5b0a6995e3b869.6941846615274090459328.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='Norwich',
                    style={'background':'url("/assets/Norwich_City.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
                html.Button(id='QPR',
                    style={'background':'url("/assets/Queens_Park_Rangers_crest.svg.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='Swansea',
                    style={'background':'url("/assets/Swansea_City_AFC_logo.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='Reading',
                    style={'background':'url("/assets/Reading.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        html.Button(id='Southampton',
                    style={'background':'url("/assets/southampton-fc-1-logo-png-transparent.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn'),         
        ],className='col  btn-group-vertical btn-block'),
        html.Div([

        html.Button(id='Cardiff',
                    style={'background':'url("/assets/Cardiff.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'), 
        html.Button(id='Crystal Palace',
                    style={'background':'url("/assets/20170616035405!Crystal_Palace_FC_logo.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),       
        html.Button(id='Hull',
                    style={'background':'url("/assets/Hull_City_Crest_2019.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),       
        html.Button(id='Burnley',
                    style={'background':'url("/assets/20180720011704!Burnley_FC_badge.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),    
        html.Button(id='Leicester',
                    style={'background':'url("/assets/Leicester_City_crest.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),     
        html.Button(id='Bournemouth',
                    style={'background':'url("/assets/1200px-AFC_Bournemouth_(2013).svg.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),        
        html.Button(id='Watford',
                    style={'background':'url("/assets/watford-fc-logo-png-transparent.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),       
        html.Button(id='Middlesbrough',
                    style={'background':'url("/assets/230px-Middlesbrough_FC_crest.svg.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),        
        html.Button(id='Brighton',
                    style={'background':'url("/assets/1200px-Brighton_&_Hove_Albion_logo.svg.png")',
                           'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),       
        html.Button(id='Huddersfield',
                    style={'background':'url("/assets/Huddersfield_Town_A.F.C._logo.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),        
        html.Button(id='Sheffield United',
                    style={'background':'url("/assets/1200px-Sheffield_United_FC_logo.svg.png")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),      
        html.Button(id='Leeds',
                    style={'background':'url("/assets/1200px-Leeds_United_F.C._logo.svg.webp")',
                          'background-size': 'contain',
                          'display': 'inline-block',
                           'outline': 'none',
                           'background-repeat': 'no-repeat'},className = 'btn btn-block'),
        ],className='col d-flex  btn-group-vertical'),
        ],className='row', style = {"height":"100%"}),

        ],className='col-1'),

    html.Div([
        html.H5('Team Statistics over 10 Years',style={'textAlign':'center'},className = 'card-header'),
        html.Div([
            dcc.Graph(id='my_Ddiv_new')
        ],className = 'card-body')
    ],className='card border-dark mb-1 col-md'),
        html.Div([
        html.H5('Home Vs Away',style={'textAlign':'center'},className = 'card-header'),
        html.Div([
            dcc.Graph(id='my_Ddiv'),
        ],className = 'card-body')
    ],className='card border-dark mb-1 col-md'),
   
    ],className = 'row g-md-1'),


    
    
],className='container-fluid')

# %%
import plotly.graph_objects as go

@app.callback(
    Output(component_id='my_Ddiv',component_property='figure'),
    Output(component_id='my_Ddiv_new',component_property='figure'),
    Output(component_id='team_name',component_property='children'),
    Output(component_id='Matches',component_property='children'),
    Output(component_id='season',component_property='children'),
    Output(component_id='win_rate',component_property='children'),
    Output(component_id='goals_rate',component_property='children'),
    Input(component_id='Arsenal',component_property='n_clicks'),
    Input(component_id='Aston Villa',component_property='n_clicks'),
    Input(component_id='Birmingham',component_property='n_clicks'),
    Input(component_id='Blackburn',component_property='n_clicks'),
    Input(component_id='Blackpool',component_property='n_clicks'),
    Input(component_id='Bolton',component_property='n_clicks'),
    Input(component_id='Chelsea',component_property='n_clicks'),
    Input(component_id='Everton',component_property='n_clicks'),
    Input(component_id='Fulham',component_property='n_clicks'),
    Input(component_id='Liverpool',component_property='n_clicks'),
    Input(component_id='Man City',component_property='n_clicks'),
    Input(component_id='Man United',component_property='n_clicks'),
    Input(component_id='Newcastle',component_property='n_clicks'),
    Input(component_id='Stoke',component_property='n_clicks'),
    Input(component_id='Sunderland',component_property='n_clicks'),
    Input(component_id='Tottenham',component_property='n_clicks'),
    Input(component_id='West Brom',component_property='n_clicks'),
    Input(component_id='West Ham',component_property='n_clicks'),
    Input(component_id='Wigan',component_property='n_clicks'),
    Input(component_id='Wolves',component_property='n_clicks'),
    Input(component_id='Norwich',component_property='n_clicks'),
    Input(component_id='QPR',component_property='n_clicks'),
    Input(component_id='Swansea',component_property='n_clicks'),
    Input(component_id='Reading',component_property='n_clicks'),
    Input(component_id='Southampton',component_property='n_clicks'),
    Input(component_id='Cardiff',component_property='n_clicks'),
    Input(component_id='Crystal Palace',component_property='n_clicks'),
    Input(component_id='Hull',component_property='n_clicks'),
    Input(component_id='Burnley',component_property='n_clicks'),
    Input(component_id='Leicester',component_property='n_clicks'),
    Input(component_id='Bournemouth',component_property='n_clicks'),
    Input(component_id='Watford',component_property='n_clicks'),
    Input(component_id='Middlesbrough',component_property='n_clicks'),
    Input(component_id='Brighton',component_property='n_clicks'),
    Input(component_id='Huddersfield',component_property='n_clicks'),
    Input(component_id='Sheffield United',component_property='n_clicks'),
    Input(component_id='Leeds',component_property='n_clicks'),
)
def update_My_Div(Arsenal,AstonVilla,Birmingham,Blackburn,Blackpool,
                  Bolton,Chelsea,Everton,Fulham,Liverpool,ManCity,ManUnited,
                  Newcastle,Stoke,Sunderland,Tottenham,WestBrom,WestHam,Wigan,
                  Wolves,Norwich,QPR,Swansea,Reading,Southampton,Cardiff,CrystalPalace,
                  Hull,Burnley,Leicester,Bournemouth,Watford,Middlesbrough,Brighton,
                  Huddersfield,SheffieldUnited,Leeds):
    ctx = dash.callback_context
    if not ctx.triggered:
        input_value = 'Arsenal'
    else:
        input_value = ctx.triggered[0]['prop_id'].split('.')[0]
    number_of_matches = len(df8[(df8['HomeTeam'] == input_value) | (df8['AwayTeam'] == input_value)])
    seasons = number_of_matches / 38
    win_h = df8[(df8['HomeTeam'] == input_value) & (df8['FTR'] == 'H') ]['HomeTeam'].count()
    draw_h = df8[(df8['HomeTeam'] == input_value) & (df8['FTR'] == 'D') ]['HomeTeam'].count()
    loss_h = df8[(df8['HomeTeam'] == input_value) & (df8['FTR'] == 'A') ]['HomeTeam'].count()
    loss_a = df8[(df8['AwayTeam'] == input_value) & (df8['FTR'] == 'H') ]['AwayTeam'].count()
    draw_a = df8[(df8['AwayTeam'] == input_value) & (df8['FTR'] == 'D') ]['AwayTeam'].count()
    win_a = df8[(df8['AwayTeam'] == input_value) & (df8['FTR'] == 'A') ]['AwayTeam'].count()
    wins_rate = round(((win_h + win_a) / number_of_matches) * 100,2)
    fig = go.Figure()
    fig.add_trace(go.Bar(
        y = ['Loss', 'Draw', 'Win'],
        x = [loss_a, draw_a, win_a],
        name = 'Away',
        orientation='h',
        marker=dict(
            color='rgba(243, 32, 32, 0.6)',
            line=dict(color='rgba(243, 32, 32, 1.0)', width=3)
        )
    ))
    fig.add_trace(go.Bar(
        y = ['Loss', 'Draw', 'Win'],
        x = [loss_h, draw_h, win_h],
        name = 'Home',
        orientation = 'h',
        marker = dict(
            color='rgba(12, 255, 68, 0.6)',
            line=dict(color='rgba(12, 255, 68, 1.0)', width=3)
        )
    ))
    fig.update_layout(barmode='stack')
#     fig =go.Figure(go.Sunburst(
#         labels=[input_value, "Home","Win","Draw","Loss","Away","Win.","Draw.","Loss."],
#         parents=["", input_value, "Home", "Home", "Home",input_value,"Away","Away","Away"],
#         values=[win_h+draw_h+loss_h+loss_a+draw_a+win_a, win_h+draw_h+loss_h, win_h, draw_h, loss_h,
#                 win_a+draw_a+loss_a, win_a, draw_a, loss_a],
#     ))
    
    home_corners = df8[(df8['HomeTeam'] == input_value)]['HC'].sum()
    home_fouls_committed = df8[(df8['HomeTeam'] == input_value)]['HF'].sum()
    home_yellow_cards = df8[(df8['HomeTeam'] == input_value)]['HY'].sum()
    home_red_cards = df8[(df8['HomeTeam'] == input_value)]['HR'].sum()
    away_corners = df8[(df8['AwayTeam'] == input_value)]['AC'].sum()
    away_fouls_committed = df8[(df8['AwayTeam'] == input_value)]['AF'].sum()
    away_yellow_cards = df8[(df8['AwayTeam'] == input_value)]['AY'].sum()
    away_red_cards = df8[(df8['AwayTeam'] == input_value)]['AR'].sum()
    home_total_shots = df8[(df8['HomeTeam'] == input_value)]['HS'].sum()
    home_target_shots = df8[(df8['HomeTeam'] == input_value)]['HST'].sum()
    home_goals = df8[(df8['HomeTeam'] == input_value)]['FTHG'].sum()
    away_total_shots = df8[(df8['AwayTeam'] == input_value)]['HS'].sum()
    away_target_shots = df8[(df8['AwayTeam'] == input_value)]['HST'].sum()
    away_goals = df8[(df8['AwayTeam'] == input_value)]['FTHG'].sum()
    goals_rate = round((home_goals + away_goals) / number_of_matches,2)


    Home_stat = (home_corners + home_fouls_committed + home_yellow_cards + home_red_cards)
    Away_stat = (away_corners + away_fouls_committed + away_yellow_cards + away_red_cards)
    statistics = Home_stat + Away_stat
    Attacking = home_total_shots + away_total_shots
    summary = Attacking + statistics
             
    fig2 = go.Figure(go.Sunburst(
        ids = [input_value, 'statistics','Attacking','Home_stat','Away_stat','Home_attack','Away_attack',
               'Corners_Home','Fouls_Committed_Home','Yellow_cards_Home','Red_Cards_Home',
               'Corners_Away','Fouls_Committed_Away','Yellow_cards_Away','Red_Cards_Away',
               'home_total_shots','home_target_shots','home_goals',
               'away_total_shots' , 'away_target_shots' , 'away_goals'
               ],
        labels = [input_value,'statistics','Attacking','Home','Away','Home_shots','Away_shots',
                  'Corners','Fouls<br>Committed','Yellow<br>cards','Red<br>Cards',
                  'Corners','Fouls<br>Committed','Yellow<br>cards','Red<br>Cards',
                  'Shots on Target','Goals',
                  'Shots on Target','Goals'
                 ],

        parents=["", input_value, input_value, "statistics","statistics",'Attacking','Attacking',
                 "Home_stat",'Home_stat',"Home_stat","Home_stat",
                 "Away_stat",'Away_stat','Away_stat','Away_stat',
                 'Home_attack','Home_attack',
                 'Away_attack','Away_attack'
                ],

        values=[summary,statistics,Attacking,Home_stat,Away_stat,home_total_shots,away_total_shots,
                home_corners , home_fouls_committed , home_yellow_cards , home_red_cards ,
               away_corners , away_fouls_committed , away_yellow_cards , away_red_cards,
                home_target_shots,home_goals,
                away_target_shots,away_goals
               ],
    ))
    return fig,fig2,input_value,number_of_matches,seasons,f'{wins_rate} %',goals_rate

# %%
import plotly.graph_objects as go

@app.callback(
    Output(component_id='g4',component_property='figure'),
    Input(component_id='my-slider10',component_property='value'),
)
def update_My_slider(year):
    figure=px.scatter(df3[df3['Season'] == year],x='total_goals',y='FTR',color='HomeTeam',labels={'total_goals':'Total Number of Goals','FTR':'Number Of Wins'},symbol='HomeTeam',text='HomeTeam').update_traces(textposition="top center",mode='markers+lines')


    return figure

# %%
app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [06/Nov/2021 09:26:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Nov/2021 09:26:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Nov/2021 09:26:35] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Nov/2021 09:26:35] "GET /_favicon.ico?v=2.0.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Nov/2021 09:26:35] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Nov/2021 09:26:35] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Nov/2021 09:26:35] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# ...
